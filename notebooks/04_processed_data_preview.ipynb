# %% [markdown]
# # 📋 Notebook 04 — Aperçu des Tables Traitées (Processed Data Preview)
#
# **Objectif :** Afficher sous forme de tableaux interactifs les colonnes, les types de données, et les **5 premières lignes** de chaque table générée dans `data/processed`.

# %%
import os
import pandas as pd

# Afficher toutes les colonnes sans coupure
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

PROCESSED_DIR = "../data/processed"

# %% [markdown]
# ## 📅 1. Table : Commandes (Factures) — `commandes_clean.csv`

# %%
df_cmd = pd.read_csv(os.path.join(PROCESSED_DIR, "commandes_clean.csv"))
print(f"Dimensions de la table : {df_cmd.shape[0]} lignes × {df_cmd.shape[1]} colonnes\n")
df_cmd.info()
df_cmd.head(5)
# Out:
# Dimensions de la table : 51784 lignes × 10 colonnes
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51784 entries, 0 to 51783
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   code_facture    51784 non-null  object
#  1   code_client     51784 non-null  object
#  2   date_commande   51784 non-null  object
#  3   ref_commercial  51784 non-null  object
#  4   societe         51784 non-null  object
#  5   mois            51784 non-null  int64
#  6   annee           51784 non-null  int64
#  7   annee_mois      51784 non-null  object
#  8   jour_semaine    51784 non-null  int64
#  9   trimestre       51784 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 4.0+ MB
#     code_facture code_client date_commande ref_commercial societe  mois  annee annee_mois  jour_semaine  trimestre
# ...

# %% [markdown]
# ## 🏷️ 2. Table : Lignes de Commandes — `lignes_clean.csv`

# %%
df_lignes = pd.read_csv(os.path.join(PROCESSED_DIR, "lignes_clean.csv"))
print(f"Dimensions de la table : {df_lignes.shape[0]} lignes × {df_lignes.shape[1]} colonnes\n")
df_lignes.info()
df_lignes.head(5)
# Out:
# Dimensions de la table : 199234 lignes × 7 colonnes
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199234 entries, 0 to 199233
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   code_facture   199234 non-null  object
#  1   quantite       199234 non-null  float64
#  2   code_article   199234 non-null  object
#  3   designation    199234 non-null  object
#  4   categorie      199234 non-null  object
#  5   societe_ligne  199234 non-null  object
#  6   is_bulk_order  199234 non-null  bool
# dtypes: bool(1), float64(1), object(5)
# memory usage: 9.3+ MB
#     code_facture  quantite   code_article               designation    categorie societe_ligne  is_bulk_order
# 0  V24-FAC+00007      20.0  4895180797071           ITEL 2163 BLACK  GSM ITEL-FP       NEWTECH          False
# 1  V24-FAC+00007      10.0  4895180797088       ITEL 2163 DEEP BLEU  GSM ITEL-FP       NEWTECH          False
# ...

# %% [markdown]
# ## 🗺️ 3. Table : Coordonnées GPS des Clients — `gps_clean.csv`

# %%
df_gps = pd.read_csv(os.path.join(PROCESSED_DIR, "gps_clean.csv"))
print(f"Dimensions de la table : {df_gps.shape[0]} lignes × {df_gps.shape[1]} colonnes\n")
df_gps.info()
df_gps.head(5)
# Out:
# Dimensions de la table : 1057 lignes × 4 colonnes
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1057 entries, 0 to 1056
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   latitude     1057 non-null   float64
#  1   longitude    1057 non-null   float64
#  2   code_client  1057 non-null   object
#  3   societe      1057 non-null   object
# dtypes: float64(2), object(2)
# memory usage: 33.2+ KB
#     latitude  longitude code_client  societe
# 0  34.745573  10.763172   CLT000003  NEWTECH
# 1  33.863429  10.861891   CLT000009  NEWTECH
# 2  35.625604  10.760409   CLT000043  NEWTECH
# 3  37.154255   9.792307   CLT000073  NEWTECH
# 4  37.271282   9.869551   CLT000076  NEWTECH

# %% [markdown]
# ## 🤖 4. Table : Matrice des Variables (Features) — `feature_matrix.csv`

# %%
df_features = pd.read_csv(os.path.join(PROCESSED_DIR, "feature_matrix.csv"))
print(f"Dimensions de la table : {df_features.shape[0]} lignes × {df_features.shape[1]} colonnes\n")
df_features.info()
df_features.head(5)
# Out:
# Dimensions de la table : 105960 lignes × 29 colonnes
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105960 entries, 0 to 105959
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   code_client             105960 non-null  object
#  1   code_article            105960 non-null  object
#  2   avg_qty                 105960 non-null  float64
#  3   std_qty                 105960 non-null  float64
#  4   min_qty                 105960 non-null  float64
#  5   max_qty                 105960 non-null  float64
#  6   total_qty               105960 non-null  float64
#  7   frequency               105960 non-null  int64
#  8   last_qty                105960 non-null  float64
#  9   recency_days            105960 non-null  int64
#  10  avg_delay_days          105960 non-null  float64
#  11  recency_relative        105960 non-null  float64
# ...
